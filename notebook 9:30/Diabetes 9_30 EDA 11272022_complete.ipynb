# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
way_1_import = pd.read_csv('C:\\Users\\LENOVO\\Downloads\\Datasets\\diabetes - Classification.csv')
way_1_import.head()
# Out:
#    Pregnancies  Glucose  Blood Pressure  SkinThickness  Insulin   BMI  \
# 0          NaN      148            72.0             35        0  33.6
# 1          1.0       85             NaN             29        0  26.6
# 2          8.0      183            64.0              0        0   NaN
# 3          1.0       89            66.0             23       94   NaN
# 4          0.0      137            40.0             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
way_2_import = pd.read_csv(r'C:\Users\LENOVO\Downloads\Datasets\diabetes - Classification.csv')
way_2_import.head()
# Out:
#    Pregnancies  Glucose  Blood Pressure  SkinThickness  Insulin   BMI  \
# 0          NaN      148            72.0             35        0  33.6
# 1          1.0       85             NaN             29        0  26.6
# 2          8.0      183            64.0              0        0   NaN
# 3          1.0       89            66.0             23       94   NaN
# 4          0.0      137            40.0             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# way_3_import = pd.read_csv('diabetes - Classification.csv')
# way_3_import.head()

# %%
df1 = pd.read_csv(r'C:\Users\LENOVO\Downloads\Datasets\diabetes - Classification.csv')
df1.tail()
# Out:
#      Pregnancies  Glucose  Blood Pressure  SkinThickness  Insulin   BMI  \
# 763         10.0      101            76.0             48      180  32.9
# 764          2.0      122            70.0             27        0  36.8
# 765          5.0      121            72.0             23      112  26.2
# 766          1.0      126            60.0              0        0  30.1
# 767          1.0       93            70.0             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
df1.tail(2)
# Out:
#      Pregnancies  Glucose  Blood Pressure  SkinThickness  Insulin   BMI  \
# 766          1.0      126            60.0              0        0  30.1
# 767          1.0       93            70.0             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
df1 = pd.read_excel(r'C:\Users\LENOVO\Downloads\Datasets\excel_diabetes - Classification.xlsx', sheet_name = 'Sheet1')
df1.head()
# Out:
#    Pregnancies  Glucose  BloodPressure
# 0            6      148             72
# 1            1       85             66
# 2            8      183             64
# 3            1       89             66
# 4            0      137             40

# %%
df1_tab2 = pd.read_excel(r'C:\Users\LENOVO\Downloads\Datasets\excel_diabetes - Classification.xlsx', sheet_name = 'Sheet1')
df1_tab1 = pd.read_excel(r'C:\Users\LENOVO\Downloads\Datasets\excel_diabetes - Classification.xlsx', sheet_name = 'diabetes - Classification')

# %%
df1_tab2
# Out:
#      Pregnancies  Glucose  BloodPressure
# 0              6      148             72
# 1              1       85             66
# 2              8      183             64
# 3              1       89             66
# 4              0      137             40
# ..           ...      ...            ...
# 763           10      101             76
# 764            2      122             70
# 765            5      121             72
# 766            1      126             60
# 767            1       93             70
#
# [768 rows x 3 columns]

# %%
df1 = pd.read_csv(r'C:\Users\LENOVO\Downloads\Datasets\diabetes - Classification.csv', names = ['Pregnancy', 'glucose', 'BP', 'ST', 'In', 'bmi', 'DPF', 'Ag', 'Ou'])
df1.head()
# Out:
#      Pregnancy  glucose              BP             ST       In   bmi  \
# 0  Pregnancies  Glucose  Blood Pressure  SkinThickness  Insulin   BMI
# 1          NaN      148              72             35        0  33.6
# 2            1       85             NaN             29        0  26.6
# 3            8      183              64              0        0   NaN
# 4            1       89              66             23       94   NaN
#
#                         DPF   Ag       Ou
# 0  DiabetesPedigreeFunction  Age  Outcome
# 1                     0.627   50        1
# 2                     0.351   31        0
# 3                     0.672   32        1
# 4                     0.167   21        0

# %%
df1.columns
# Out:
# Index(['Pregnancy', 'glucose', 'BP', 'ST', 'In', 'bmi', 'DPF', 'Ag', 'Ou'], dtype='object')

# %%
df1.drop(0)
# Out:
#     Pregnancy glucose   BP  ST   In   bmi    DPF  Ag Ou
# 1         NaN     148   72  35    0  33.6  0.627  50  1
# 2           1      85  NaN  29    0  26.6  0.351  31  0
# 3           8     183   64   0    0   NaN  0.672  32  1
# 4           1      89   66  23   94   NaN  0.167  21  0
# 5           0     137   40  35  168  43.1  2.288  33  1
# ..        ...     ...  ...  ..  ...   ...    ...  .. ..
# 764        10     101   76  48  180  32.9  0.171  63  0
# 765         2     122   70  27    0  36.8   0.34  27  0
# 766         5     121   72  23  112  26.2  0.245  30  0
# 767         1     126   60   0    0  30.1  0.349  47  1
# 768         1      93   70  31    0  30.4  0.315  23  0
#
# [768 rows x 9 columns]

# %%
df1 = pd.read_csv(r'C:\Users\LENOVO\Downloads\Datasets\diabetes - Classification.csv')
df1.head()
# Out:
#    Pregnancies  Glucose  Blood Pressure  SkinThickness  Insulin   BMI  \
# 0          NaN      148            72.0             35        0  33.6
# 1          1.0       85             NaN             29        0  26.6
# 2          8.0      183            64.0              0        0   NaN
# 3          1.0       89            66.0             23       94   NaN
# 4          0.0      137            40.0             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df1 = pd.read_csv(r'C:\Users\LENOVO\Downloads\Datasets\diabetes - Classification.csv', usecols = ['Pregnancies', 'Age', 'BMI'])
df1.head(10)
# Out:
#    Pregnancies   BMI  Age
# 0          NaN  33.6   50
# 1          1.0  26.6   31
# 2          8.0   NaN   32
# 3          1.0   NaN   21
# 4          0.0  43.1   33
# 5          5.0  25.6   30
# 6          3.0  31.0   26
# 7         10.0  35.3   29
# 8          2.0  30.5   53
# 9          8.0   0.0   54

# %%
df1 = pd.read_csv(r'C:\Users\LENOVO\Downloads\Datasets\diabetes - Classification.csv')
df1.head()
# Out:
#    Pregnancies  Glucose  Blood Pressure  SkinThickness  Insulin   BMI  \
# 0          NaN      148            72.0             35        0  33.6
# 1          1.0       85             NaN             29        0  26.6
# 2          8.0      183            64.0              0        0   NaN
# 3          1.0       89            66.0             23       94   NaN
# 4          0.0      137            40.0             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df1 = pd.read_csv(r'C:\Users\LENOVO\Downloads\Datasets\diabetes - Classification.csv', skiprows = 2)
df1.head()
# Out:
#    1   85  Unnamed: 2  29    0  26.6  0.351  31  0.1
# 0  8  183          64   0    0   NaN  0.672  32    1
# 1  1   89          66  23   94   NaN  0.167  21    0
# 2  0  137          40  35  168  43.1  2.288  33    1
# 3  5  116          74   0    0  25.6  0.201  30    0
# 4  3   78          50  32   88  31.0  0.248  26    1

# %%
df1 = pd.read_csv(r'C:\Users\LENOVO\Downloads\Datasets\diabetes - Classification.csv', header = 2)
df1.head()
# Out:
#    1   85  Unnamed: 2  29    0  26.6  0.351  31  0.1
# 0  8  183          64   0    0   NaN  0.672  32    1
# 1  1   89          66  23   94   NaN  0.167  21    0
# 2  0  137          40  35  168  43.1  2.288  33    1
# 3  5  116          74   0    0  25.6  0.201  30    0
# 4  3   78          50  32   88  31.0  0.248  26    1

# %%
df1 = pd.read_csv(r'C:\Users\LENOVO\Downloads\Datasets\diabetes - Classification.csv', header = None)
df1.head()
# Out:
#              0        1               2              3        4     5  \
# 0  Pregnancies  Glucose  Blood Pressure  SkinThickness  Insulin   BMI
# 1          NaN      148              72             35        0  33.6
# 2            1       85             NaN             29        0  26.6
# 3            8      183              64              0        0   NaN
# 4            1       89              66             23       94   NaN
#
#                           6    7        8
# 0  DiabetesPedigreeFunction  Age  Outcome
# 1                     0.627   50        1
# 2                     0.351   31        0
# 3                     0.672   32        1
# 4                     0.167   21        0

# %%
df1 = pd.read_csv(r'C:\Users\LENOVO\Downloads\Datasets\diabetes - Classification.csv')
df1.head()
# Out:
#    Pregnancies  Glucose  Blood Pressure  SkinThickness  Insulin   BMI  \
# 0          NaN      148            72.0             35        0  33.6
# 1          1.0       85             NaN             29        0  26.6
# 2          8.0      183            64.0              0        0   NaN
# 3          1.0       89            66.0             23       94   NaN
# 4          0.0      137            40.0             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df1 = pd.read_csv(r'C:\Users\LENOVO\Downloads\Datasets\diabetes - Classification.csv', nrows = 30)
df1.shape
# Out:
# (30, 9)

# %%
df1 = pd.read_csv(r'C:\Users\LENOVO\Downloads\Datasets\diabetes - Classification.csv', nrows = 200)
df1.shape
# Out:
# (200, 9)

# %%
df1 = pd.read_csv(r'C:\Users\LENOVO\Downloads\Datasets\diabetes - Classification.csv')
df2 = df1.copy()

# %%
df2.shape
# Out:
# (768, 9)

# %%
rows, columns = df2.shape

# %%
rows
# Out:
# 768

# %%
columns
# Out:
# 9

# %%
df2.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'Blood Pressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
t20_to_50 = df2[20:51]
t20_to_50.head()
# Out:
#     Pregnancies  Glucose  Blood Pressure  SkinThickness  Insulin   BMI  \
# 20          3.0      126            88.0             41      235  39.3
# 21          8.0       99            84.0              0        0  35.4
# 22          7.0      196            90.0              0        0  39.8
# 23          9.0      119            80.0             35        0  29.0
# 24         11.0      143            94.0             33      146  36.6
#
#     DiabetesPedigreeFunction  Age  Outcome
# 20                     0.704   27        0
# 21                     0.388   50        0
# 22                     0.451   41        1
# 23                     0.263   29        1
# 24                     0.254   51        1

# %%
df2[:]
# Out:
#      Pregnancies  Glucose  Blood Pressure  SkinThickness  Insulin   BMI  \
# 0            NaN      148            72.0             35        0  33.6
# 1            1.0       85             NaN             29        0  26.6
# 2            8.0      183            64.0              0        0   NaN
# 3            1.0       89            66.0             23       94   NaN
# 4            0.0      137            40.0             35      168  43.1
# ..           ...      ...             ...            ...      ...   ...
# 763         10.0      101            76.0             48      180  32.9
# 764          2.0      122            70.0             27        0  36.8
# 765          5.0      121            72.0             23      112  26.2
# 766          1.0      126            60.0              0        0  30.1
# 767          1.0       93            70.0             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               767 non-null    float64
#  1   Glucose                   768 non-null    int64
#  2   Blood Pressure            767 non-null    float64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       766 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(4), int64(5)
# memory usage: 54.1 KB

# %%
df2.isna().sum()
# Out:
# Pregnancies                 1
# Glucose                     0
# Blood Pressure              1
# SkinThickness               0
# Insulin                     0
# BMI                         2
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df2.describe()
# Out:
#        Pregnancies     Glucose  Blood Pressure  SkinThickness     Insulin  \
# count   767.000000  768.000000      767.000000     768.000000  768.000000
# mean      3.842243  120.894531       69.109518      20.536458   79.799479
# std       3.370877   31.972618       19.368112      15.952218  115.244002
# min       0.000000    0.000000        0.000000       0.000000    0.000000
# 25%       1.000000   99.000000       62.000000       0.000000    0.000000
# 50%       3.000000  117.000000       72.000000      23.000000   30.500000
# 75%       6.000000  140.250000       80.000000      32.000000  127.250000
# max      17.000000  199.000000      122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  766.000000                768.000000  768.000000  768.000000
# mean    32.009008                  0.471876   33.240885    0.348958
# std      7.886929                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
df2.describe().T
# Out:
#                           count        mean         std     min       25%  \
# Pregnancies               767.0    3.842243    3.370877   0.000   1.00000
# Glucose                   768.0  120.894531   31.972618   0.000  99.00000
# Blood Pressure            767.0   69.109518   19.368112   0.000  62.00000
# SkinThickness             768.0   20.536458   15.952218   0.000   0.00000
# Insulin                   768.0   79.799479  115.244002   0.000   0.00000
# BMI                       766.0   32.009008    7.886929   0.000  27.30000
# DiabetesPedigreeFunction  768.0    0.471876    0.331329   0.078   0.24375
# Age                       768.0   33.240885   11.760232  21.000  24.00000
# Outcome                   768.0    0.348958    0.476951   0.000   0.00000
#
#                                50%        75%     max
# Pregnancies                 3.0000    6.00000   17.00
# Glucose                   117.0000  140.25000  199.00
# Blood Pressure             72.0000   80.00000  122.00
# SkinThickness              23.0000   32.00000   99.00
# Insulin                    30.5000  127.25000  846.00
# BMI                        32.0000   36.60000   67.10
# DiabetesPedigreeFunction    0.3725    0.62625    2.42
# Age                        29.0000   41.00000   81.00
# Outcome                     0.0000    1.00000    1.00

# %%
df2.describe().transpose()
# Out:
#                           count        mean         std     min       25%  \
# Pregnancies               767.0    3.842243    3.370877   0.000   1.00000
# Glucose                   768.0  120.894531   31.972618   0.000  99.00000
# Blood Pressure            767.0   69.109518   19.368112   0.000  62.00000
# SkinThickness             768.0   20.536458   15.952218   0.000   0.00000
# Insulin                   768.0   79.799479  115.244002   0.000   0.00000
# BMI                       766.0   32.009008    7.886929   0.000  27.30000
# DiabetesPedigreeFunction  768.0    0.471876    0.331329   0.078   0.24375
# Age                       768.0   33.240885   11.760232  21.000  24.00000
# Outcome                   768.0    0.348958    0.476951   0.000   0.00000
#
#                                50%        75%     max
# Pregnancies                 3.0000    6.00000   17.00
# Glucose                   117.0000  140.25000  199.00
# Blood Pressure             72.0000   80.00000  122.00
# SkinThickness              23.0000   32.00000   99.00
# Insulin                    30.5000  127.25000  846.00
# BMI                        32.0000   36.60000   67.10
# DiabetesPedigreeFunction    0.3725    0.62625    2.42
# Age                        29.0000   41.00000   81.00
# Outcome                     0.0000    1.00000    1.00

# %%
df2.DiabetesPedigreeFunction.describe()
# Out:
# count    768.000000
# mean       0.471876
# std        0.331329
# min        0.078000
# 25%        0.243750
# 50%        0.372500
# 75%        0.626250
# max        2.420000
# Name: DiabetesPedigreeFunction, dtype: float64

# %%
df2['DiabetesPedigreeFunction'].describe()
# Out:
# count    768.000000
# mean       0.471876
# std        0.331329
# min        0.078000
# 25%        0.243750
# 50%        0.372500
# 75%        0.626250
# max        2.420000
# Name: DiabetesPedigreeFunction, dtype: float64

# %%
# df2.Blood Pressure.describe()

# %%
df2[['Blood Pressure', 'DiabetesPedigreeFunction']].describe()
# Out:
#        Blood Pressure  DiabetesPedigreeFunction
# count      767.000000                768.000000
# mean        69.109518                  0.471876
# std         19.368112                  0.331329
# min          0.000000                  0.078000
# 25%         62.000000                  0.243750
# 50%         72.000000                  0.372500
# 75%         80.000000                  0.626250
# max        122.000000                  2.420000

# %%
df2[['Blood Pressure', 'DiabetesPedigreeFunction']].describe()
# Out:
#        Blood Pressure  DiabetesPedigreeFunction
# count      767.000000                768.000000
# mean        69.109518                  0.471876
# std         19.368112                  0.331329
# min          0.000000                  0.078000
# 25%         62.000000                  0.243750
# 50%         72.000000                  0.372500
# 75%         80.000000                  0.626250
# max        122.000000                  2.420000

# %%
type(df2['Blood Pressure'])
# Out:
# pandas.core.series.Series

# %%
type(df2[['Blood Pressure']])
# Out:
# pandas.core.frame.DataFrame

# %%
df1[['Blood Pressure']][51:101]
# Out:
#      Blood Pressure
# 51             50.0
# 52             66.0
# 53             90.0
# 54             66.0
# 55             50.0
# 56             68.0
# 57             88.0
# 58             82.0
# 59             64.0
# 60              0.0
# 61             72.0
# 62             62.0
# 63             58.0
# 64             66.0
# 65             74.0
# 66             88.0
# 67             92.0
# 68             66.0
# 69             85.0
# 70             66.0
# 71             64.0
# 72             90.0
# 73             86.0
# 74             75.0
# 75             48.0
# 76             78.0
# 77             72.0
# 78              0.0
# 79             66.0
# 80             44.0
# 81              0.0
# 82             78.0
# 83             65.0
# 84            108.0
# 85             74.0
# 86             72.0
# 87             68.0
# 88             70.0
# 89             68.0
# 90             55.0
# 91             80.0
# 92             78.0
# 93             72.0
# 94             82.0
# 95             72.0
# 96             62.0
# 97             48.0
# 98             50.0
# 99             90.0
# 100            72.0

# %%
df1[51:61]
# Out:
#     Pregnancies  Glucose  Blood Pressure  SkinThickness  Insulin   BMI  \
# 51          1.0      101            50.0             15       36  24.2
# 52          5.0       88            66.0             21       23  24.4
# 53          8.0      176            90.0             34      300  33.7
# 54          7.0      150            66.0             42      342  34.7
# 55          1.0       73            50.0             10        0  23.0
# 56          7.0      187            68.0             39      304  37.7
# 57          0.0      100            88.0             60      110  46.8
# 58          0.0      146            82.0              0        0  40.5
# 59          0.0      105            64.0             41      142  41.5
# 60          2.0       84             0.0              0        0   0.0
#
#     DiabetesPedigreeFunction  Age  Outcome
# 51                     0.526   26        0
# 52                     0.342   30        0
# 53                     0.467   58        1
# 54                     0.718   42        0
# 55                     0.248   21        0
# 56                     0.254   41        1
# 57                     0.962   31        0
# 58                     1.781   44        0
# 59                     0.173   22        0
# 60                     0.304   21        0

# %%
np.where(df2.isnull() == True)
# Out:
# (array([0, 1, 2, 3], dtype=int64), array([0, 2, 5, 5], dtype=int64))

# %%
df2
# Out:
#      Pregnancies  Glucose  Blood Pressure  SkinThickness  Insulin   BMI  \
# 0            NaN      148            72.0             35        0  33.6
# 1            1.0       85             NaN             29        0  26.6
# 2            8.0      183            64.0              0        0   NaN
# 3            1.0       89            66.0             23       94   NaN
# 4            0.0      137            40.0             35      168  43.1
# ..           ...      ...             ...            ...      ...   ...
# 763         10.0      101            76.0             48      180  32.9
# 764          2.0      122            70.0             27        0  36.8
# 765          5.0      121            72.0             23      112  26.2
# 766          1.0      126            60.0              0        0  30.1
# 767          1.0       93            70.0             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
np.where(df2['BMI'].isnull() == True)
# Out:
# (array([2, 3], dtype=int64),)

# %%
df2['BMI'].max()
# Out:
# 67.1

# %%
df2['BMI'].min()
# Out:
# 0.0

# %%
df2['BMI'].std()
# Out:
# 7.8869286951940785

# %%
df2.std()
# Out:
# Pregnancies                   3.370877
# Glucose                      31.972618
# Blood Pressure               19.368112
# SkinThickness                15.952218
# Insulin                     115.244002
# BMI                           7.886929
# DiabetesPedigreeFunction      0.331329
# Age                          11.760232
# Outcome                       0.476951
# dtype: float64

# %%
df2.max()
# Out:
# Pregnancies                  17.00
# Glucose                     199.00
# Blood Pressure              122.00
# SkinThickness                99.00
# Insulin                     846.00
# BMI                          67.10
# DiabetesPedigreeFunction      2.42
# Age                          81.00
# Outcome                       1.00
# dtype: float64

# %%
df2[df2['Glucose'] > 150]
# Out:
#      Pregnancies  Glucose  Blood Pressure  SkinThickness  Insulin   BMI  \
# 2            8.0      183            64.0              0        0   NaN
# 8            2.0      197            70.0             45      543  30.5
# 11          10.0      168            74.0              0        0  38.0
# 13           1.0      189            60.0             23      846  30.1
# 14           5.0      166            72.0             19      175  25.8
# ..           ...      ...             ...            ...      ...   ...
# 749          6.0      162            62.0              0        0  24.3
# 753          0.0      181            88.0             44      510  43.3
# 754          8.0      154            78.0             32        0  32.4
# 759          6.0      190            92.0              0        0  35.5
# 761          9.0      170            74.0             31        0  44.0
#
#      DiabetesPedigreeFunction  Age  Outcome
# 2                       0.672   32        1
# 8                       0.158   53        1
# 11                      0.537   34        1
# 13                      0.398   59        1
# 14                      0.587   51        1
# ..                        ...  ...      ...
# 749                     0.178   50        1
# 753                     0.222   26        1
# 754                     0.443   45        1
# 759                     0.278   66        1
# 761                     0.403   43        1
#
# [140 rows x 9 columns]

# %%
df2[df2['BMI'] > 25]
# Out:
#      Pregnancies  Glucose  Blood Pressure  SkinThickness  Insulin   BMI  \
# 0            NaN      148            72.0             35        0  33.6
# 1            1.0       85             NaN             29        0  26.6
# 4            0.0      137            40.0             35      168  43.1
# 5            5.0      116            74.0              0        0  25.6
# 6            3.0       78            50.0             32       88  31.0
# ..           ...      ...             ...            ...      ...   ...
# 763         10.0      101            76.0             48      180  32.9
# 764          2.0      122            70.0             27        0  36.8
# 765          5.0      121            72.0             23      112  26.2
# 766          1.0      126            60.0              0        0  30.1
# 767          1.0       93            70.0             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 4                       2.288   33        1
# 5                       0.201   30        0
# 6                       0.248   26        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [644 rows x 9 columns]

# %%
df2[(df2['BMI'] > 25) & (df2['BMI'] < 30)]
# Out:
#      Pregnancies  Glucose  Blood Pressure  SkinThickness  Insulin   BMI  \
# 1            1.0       85             NaN             29        0  26.6
# 5            5.0      116            74.0              0        0  25.6
# 12          10.0      139            80.0              0        0  27.1
# 14           5.0      166            72.0             19      175  25.8
# 17           7.0      107            74.0              0        0  29.6
# ..           ...      ...             ...            ...      ...   ...
# 736          0.0      126            86.0             27      120  27.4
# 742          1.0      109            58.0             18      116  28.5
# 752          3.0      108            62.0             24        0  26.0
# 760          2.0       88            58.0             26       16  28.4
# 765          5.0      121            72.0             23      112  26.2
#
#      DiabetesPedigreeFunction  Age  Outcome
# 1                       0.351   31        0
# 5                       0.201   30        0
# 12                      1.441   57        0
# 14                      0.587   51        1
# 17                      0.254   31        1
# ..                        ...  ...      ...
# 736                     0.515   21        0
# 742                     0.219   22        0
# 752                     0.223   25        0
# 760                     0.766   22        0
# 765                     0.245   30        0
#
# [172 rows x 9 columns]

# %%
df2[(df2['BMI'] > 25) | (df2['SkinThickness'] > 40)]
# Out:
#      Pregnancies  Glucose  Blood Pressure  SkinThickness  Insulin   BMI  \
# 0            NaN      148            72.0             35        0  33.6
# 1            1.0       85             NaN             29        0  26.6
# 4            0.0      137            40.0             35      168  43.1
# 5            5.0      116            74.0              0        0  25.6
# 6            3.0       78            50.0             32       88  31.0
# ..           ...      ...             ...            ...      ...   ...
# 763         10.0      101            76.0             48      180  32.9
# 764          2.0      122            70.0             27        0  36.8
# 765          5.0      121            72.0             23      112  26.2
# 766          1.0      126            60.0              0        0  30.1
# 767          1.0       93            70.0             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 4                       2.288   33        1
# 5                       0.201   30        0
# 6                       0.248   26        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [644 rows x 9 columns]

# %%
df1[df1['BMI'] == df2['BMI'].max()]
# Out:
#      Pregnancies  Glucose  Blood Pressure  SkinThickness  Insulin   BMI  \
# 177          0.0      129           110.0             46      130  67.1
#
#      DiabetesPedigreeFunction  Age  Outcome
# 177                     0.319   26        1

# %%
df2['BMI'].max()
# Out:
# 67.1

# %%
#df1[df1['BMI'] == 67.1]

# %%
df1['BMI']
# Out:
# 0      33.6
# 1      26.6
# 2       NaN
# 3       NaN
# 4      43.1
#        ...
# 763    32.9
# 764    36.8
# 765    26.2
# 766    30.1
# 767    30.4
# Name: BMI, Length: 768, dtype: float64

# %%
df1[df1['BMI'] == df2['BMI'].min()]
# Out:
#      Pregnancies  Glucose  Blood Pressure  SkinThickness  Insulin  BMI  \
# 9            8.0      125            96.0              0        0  0.0
# 49           7.0      105             0.0              0        0  0.0
# 60           2.0       84             0.0              0        0  0.0
# 81           2.0       74             0.0              0        0  0.0
# 145          0.0      102            75.0             23        0  0.0
# 371          0.0      118            64.0             23       89  0.0
# 426          0.0       94             0.0              0        0  0.0
# 494          3.0       80             0.0              0        0  0.0
# 522          6.0      114             0.0              0        0  0.0
# 684          5.0      136            82.0              0        0  0.0
# 706         10.0      115             0.0              0        0  0.0
#
#      DiabetesPedigreeFunction  Age  Outcome
# 9                       0.232   54        1
# 49                      0.305   24        0
# 60                      0.304   21        0
# 81                      0.102   22        0
# 145                     0.572   21        0
# 371                     1.731   21        0
# 426                     0.256   25        0
# 494                     0.174   22        0
# 522                     0.189   26        0
# 684                     0.640   69        0
# 706                     0.261   30        1

# %%
random_df = df1[df1['BMI'] == df2['BMI'].min()]
random_df
# Out:
#      Pregnancies  Glucose  Blood Pressure  SkinThickness  Insulin  BMI  \
# 9            8.0      125            96.0              0        0  0.0
# 49           7.0      105             0.0              0        0  0.0
# 60           2.0       84             0.0              0        0  0.0
# 81           2.0       74             0.0              0        0  0.0
# 145          0.0      102            75.0             23        0  0.0
# 371          0.0      118            64.0             23       89  0.0
# 426          0.0       94             0.0              0        0  0.0
# 494          3.0       80             0.0              0        0  0.0
# 522          6.0      114             0.0              0        0  0.0
# 684          5.0      136            82.0              0        0  0.0
# 706         10.0      115             0.0              0        0  0.0
#
#      DiabetesPedigreeFunction  Age  Outcome
# 9                       0.232   54        1
# 49                      0.305   24        0
# 60                      0.304   21        0
# 81                      0.102   22        0
# 145                     0.572   21        0
# 371                     1.731   21        0
# 426                     0.256   25        0
# 494                     0.174   22        0
# 522                     0.189   26        0
# 684                     0.640   69        0
# 706                     0.261   30        1

# %%
random_df = random_df.reset_index()

# %%
random_df
# Out:
#     index  Pregnancies  Glucose  Blood Pressure  SkinThickness  Insulin  BMI  \
# 0       9          8.0      125            96.0              0        0  0.0
# 1      49          7.0      105             0.0              0        0  0.0
# 2      60          2.0       84             0.0              0        0  0.0
# 3      81          2.0       74             0.0              0        0  0.0
# 4     145          0.0      102            75.0             23        0  0.0
# 5     371          0.0      118            64.0             23       89  0.0
# 6     426          0.0       94             0.0              0        0  0.0
# 7     494          3.0       80             0.0              0        0  0.0
# 8     522          6.0      114             0.0              0        0  0.0
# 9     684          5.0      136            82.0              0        0  0.0
# 10    706         10.0      115             0.0              0        0  0.0
#
#     DiabetesPedigreeFunction  Age  Outcome
# 0                      0.232   54        1
# 1                      0.305   24        0
# 2                      0.304   21        0
# 3                      0.102   22        0
# 4                      0.572   21        0
# 5                      1.731   21        0
# 6                      0.256   25        0
# 7                      0.174   22        0
# 8                      0.189   26        0
# 9                      0.640   69        0
# 10                     0.261   30        1

# %%
random_df.drop(['index'], axis = 1, inplace = True)

# %%
random_df
# Out:
#     Pregnancies  Glucose  Blood Pressure  SkinThickness  Insulin  BMI  \
# 0           8.0      125            96.0              0        0  0.0
# 1           7.0      105             0.0              0        0  0.0
# 2           2.0       84             0.0              0        0  0.0
# 3           2.0       74             0.0              0        0  0.0
# 4           0.0      102            75.0             23        0  0.0
# 5           0.0      118            64.0             23       89  0.0
# 6           0.0       94             0.0              0        0  0.0
# 7           3.0       80             0.0              0        0  0.0
# 8           6.0      114             0.0              0        0  0.0
# 9           5.0      136            82.0              0        0  0.0
# 10         10.0      115             0.0              0        0  0.0
#
#     DiabetesPedigreeFunction  Age  Outcome
# 0                      0.232   54        1
# 1                      0.305   24        0
# 2                      0.304   21        0
# 3                      0.102   22        0
# 4                      0.572   21        0
# 5                      1.731   21        0
# 6                      0.256   25        0
# 7                      0.174   22        0
# 8                      0.189   26        0
# 9                      0.640   69        0
# 10                     0.261   30        1

# %%
random_df.to_csv('testing1.csv', index = False)

# %%
random_df.to_excel('testing2.xlsx', index = False)

# %%
random_df.to_excel('Downloads\\testing3.xlsx', index = False, sheet_name = 'BMI_0')

# %%
random_df.to_excel('Downloads\\testing3.xlsx', index = False, sheet_name = 'BMI_1')

# %%
df2.isna().sum()
# Out:
# Pregnancies                 1
# Glucose                     0
# Blood Pressure              1
# SkinThickness               0
# Insulin                     0
# BMI                         2
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df3 = df2.fillna(100)
df3
# Out:
#      Pregnancies  Glucose  Blood Pressure  SkinThickness  Insulin    BMI  \
# 0          100.0      148            72.0             35        0   33.6
# 1            1.0       85           100.0             29        0   26.6
# 2            8.0      183            64.0              0        0  100.0
# 3            1.0       89            66.0             23       94  100.0
# 4            0.0      137            40.0             35      168   43.1
# ..           ...      ...             ...            ...      ...    ...
# 763         10.0      101            76.0             48      180   32.9
# 764          2.0      122            70.0             27        0   36.8
# 765          5.0      121            72.0             23      112   26.2
# 766          1.0      126            60.0              0        0   30.1
# 767          1.0       93            70.0             31        0   30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
df4 = df2.fillna(df2.median())
df4.head()
# Out:
#    Pregnancies  Glucose  Blood Pressure  SkinThickness  Insulin   BMI  \
# 0          3.0      148            72.0             35        0  33.6
# 1          1.0       85            72.0             29        0  26.6
# 2          8.0      183            64.0              0        0  32.0
# 3          1.0       89            66.0             23       94  32.0
# 4          0.0      137            40.0             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df4 = df2.fillna(df2.mean())
df4.head()
# Out:
#    Pregnancies  Glucose  Blood Pressure  SkinThickness  Insulin        BMI  \
# 0     3.842243      148       72.000000             35        0  33.600000
# 1     1.000000       85       69.109518             29        0  26.600000
# 2     8.000000      183       64.000000              0        0  32.009008
# 3     1.000000       89       66.000000             23       94  32.009008
# 4     0.000000      137       40.000000             35      168  43.100000
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df3 = df2.copy()

# %%
df3['BMI'] = df3['BMI'].fillna(df3['BMI'].median())
df3.head()
# Out:
#    Pregnancies  Glucose  Blood Pressure  SkinThickness  Insulin   BMI  \
# 0          NaN      148            72.0             35        0  33.6
# 1          1.0       85             NaN             29        0  26.6
# 2          8.0      183            64.0              0        0  32.0
# 3          1.0       89            66.0             23       94  32.0
# 4          0.0      137            40.0             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df3['Blood Pressure'] = df3['Blood Pressure'].fillna(df3['Blood Pressure'].median())
df3.head()
# Out:
#    Pregnancies  Glucose  Blood Pressure  SkinThickness  Insulin   BMI  \
# 0          NaN      148            72.0             35        0  33.6
# 1          1.0       85            72.0             29        0  26.6
# 2          8.0      183            64.0              0        0  32.0
# 3          1.0       89            66.0             23       94  32.0
# 4          0.0      137            40.0             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df5 = df2.fillna({
    'Pregnancies' : 0,
    'Blood Pressure': df2['Blood Pressure'].median(),
    'BMI': df2['BMI'].median()
})

# %%
df5.head()
# Out:
#    Pregnancies  Glucose  Blood Pressure  SkinThickness  Insulin   BMI  \
# 0          0.0      148            72.0             35        0  33.6
# 1          1.0       85            72.0             29        0  26.6
# 2          8.0      183            64.0              0        0  32.0
# 3          1.0       89            66.0             23       94  32.0
# 4          0.0      137            40.0             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df6 = df2.copy()

# %%
df6_1 = df6.fillna(method = 'ffill')
df6_1
# Out:
#      Pregnancies  Glucose  Blood Pressure  SkinThickness  Insulin   BMI  \
# 0            NaN      148            72.0             35        0  33.6
# 1            1.0       85            72.0             29        0  26.6
# 2            8.0      183            64.0              0        0  26.6
# 3            1.0       89            66.0             23       94  26.6
# 4            0.0      137            40.0             35      168  43.1
# ..           ...      ...             ...            ...      ...   ...
# 763         10.0      101            76.0             48      180  32.9
# 764          2.0      122            70.0             27        0  36.8
# 765          5.0      121            72.0             23      112  26.2
# 766          1.0      126            60.0              0        0  30.1
# 767          1.0       93            70.0             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
df6_2 = df6.fillna(method = 'bfill')
df6_2
# Out:
#      Pregnancies  Glucose  Blood Pressure  SkinThickness  Insulin   BMI  \
# 0            1.0      148            72.0             35        0  33.6
# 1            1.0       85            64.0             29        0  26.6
# 2            8.0      183            64.0              0        0  43.1
# 3            1.0       89            66.0             23       94  43.1
# 4            0.0      137            40.0             35      168  43.1
# ..           ...      ...             ...            ...      ...   ...
# 763         10.0      101            76.0             48      180  32.9
# 764          2.0      122            70.0             27        0  36.8
# 765          5.0      121            72.0             23      112  26.2
# 766          1.0      126            60.0              0        0  30.1
# 767          1.0       93            70.0             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
df6_3 = df6.fillna(method = 'bfill', limit = 1)
df6_3
# Out:
#      Pregnancies  Glucose  Blood Pressure  SkinThickness  Insulin   BMI  \
# 0            1.0      148            72.0             35        0  33.6
# 1            1.0       85            64.0             29        0  26.6
# 2            8.0      183            64.0              0        0   NaN
# 3            1.0       89            66.0             23       94  43.1
# 4            0.0      137            40.0             35      168  43.1
# ..           ...      ...             ...            ...      ...   ...
# 763         10.0      101            76.0             48      180  32.9
# 764          2.0      122            70.0             27        0  36.8
# 765          5.0      121            72.0             23      112  26.2
# 766          1.0      126            60.0              0        0  30.1
# 767          1.0       93            70.0             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
df6_4 = df6.fillna(method = 'ffill', axis = 'columns')
df6_4
# Out:
#      Pregnancies  Glucose  Blood Pressure  SkinThickness  Insulin   BMI  \
# 0            NaN    148.0            72.0           35.0      0.0  33.6
# 1            1.0     85.0            85.0           29.0      0.0  26.6
# 2            8.0    183.0            64.0            0.0      0.0   0.0
# 3            1.0     89.0            66.0           23.0     94.0  94.0
# 4            0.0    137.0            40.0           35.0    168.0  43.1
# ..           ...      ...             ...            ...      ...   ...
# 763         10.0    101.0            76.0           48.0    180.0  32.9
# 764          2.0    122.0            70.0           27.0      0.0  36.8
# 765          5.0    121.0            72.0           23.0    112.0  26.2
# 766          1.0    126.0            60.0            0.0      0.0  30.1
# 767          1.0     93.0            70.0           31.0      0.0  30.4
#
#      DiabetesPedigreeFunction   Age  Outcome
# 0                       0.627  50.0      1.0
# 1                       0.351  31.0      0.0
# 2                       0.672  32.0      1.0
# 3                       0.167  21.0      0.0
# 4                       2.288  33.0      1.0
# ..                        ...   ...      ...
# 763                     0.171  63.0      0.0
# 764                     0.340  27.0      0.0
# 765                     0.245  30.0      0.0
# 766                     0.349  47.0      1.0
# 767                     0.315  23.0      0.0
#
# [768 rows x 9 columns]

# %%
df6_4 = df6.fillna(method = 'ffill', axis = 1)
df6_4
# Out:
#      Pregnancies  Glucose  Blood Pressure  SkinThickness  Insulin   BMI  \
# 0            NaN    148.0            72.0           35.0      0.0  33.6
# 1            1.0     85.0            85.0           29.0      0.0  26.6
# 2            8.0    183.0            64.0            0.0      0.0   0.0
# 3            1.0     89.0            66.0           23.0     94.0  94.0
# 4            0.0    137.0            40.0           35.0    168.0  43.1
# ..           ...      ...             ...            ...      ...   ...
# 763         10.0    101.0            76.0           48.0    180.0  32.9
# 764          2.0    122.0            70.0           27.0      0.0  36.8
# 765          5.0    121.0            72.0           23.0    112.0  26.2
# 766          1.0    126.0            60.0            0.0      0.0  30.1
# 767          1.0     93.0            70.0           31.0      0.0  30.4
#
#      DiabetesPedigreeFunction   Age  Outcome
# 0                       0.627  50.0      1.0
# 1                       0.351  31.0      0.0
# 2                       0.672  32.0      1.0
# 3                       0.167  21.0      0.0
# 4                       2.288  33.0      1.0
# ..                        ...   ...      ...
# 763                     0.171  63.0      0.0
# 764                     0.340  27.0      0.0
# 765                     0.245  30.0      0.0
# 766                     0.349  47.0      1.0
# 767                     0.315  23.0      0.0
#
# [768 rows x 9 columns]

# %%
df6_4 = df6.fillna(method = 'ffill', axis = 0)
df6_4
# Out:
#      Pregnancies  Glucose  Blood Pressure  SkinThickness  Insulin   BMI  \
# 0            NaN      148            72.0             35        0  33.6
# 1            1.0       85            72.0             29        0  26.6
# 2            8.0      183            64.0              0        0  26.6
# 3            1.0       89            66.0             23       94  26.6
# 4            0.0      137            40.0             35      168  43.1
# ..           ...      ...             ...            ...      ...   ...
# 763         10.0      101            76.0             48      180  32.9
# 764          2.0      122            70.0             27        0  36.8
# 765          5.0      121            72.0             23      112  26.2
# 766          1.0      126            60.0              0        0  30.1
# 767          1.0       93            70.0             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
df6_5 = df6.fillna(method = 'bfill', axis = 1)
df6_5
# Out:
#      Pregnancies  Glucose  Blood Pressure  SkinThickness  Insulin     BMI  \
# 0          148.0    148.0            72.0           35.0      0.0  33.600
# 1            1.0     85.0            29.0           29.0      0.0  26.600
# 2            8.0    183.0            64.0            0.0      0.0   0.672
# 3            1.0     89.0            66.0           23.0     94.0   0.167
# 4            0.0    137.0            40.0           35.0    168.0  43.100
# ..           ...      ...             ...            ...      ...     ...
# 763         10.0    101.0            76.0           48.0    180.0  32.900
# 764          2.0    122.0            70.0           27.0      0.0  36.800
# 765          5.0    121.0            72.0           23.0    112.0  26.200
# 766          1.0    126.0            60.0            0.0      0.0  30.100
# 767          1.0     93.0            70.0           31.0      0.0  30.400
#
#      DiabetesPedigreeFunction   Age  Outcome
# 0                       0.627  50.0      1.0
# 1                       0.351  31.0      0.0
# 2                       0.672  32.0      1.0
# 3                       0.167  21.0      0.0
# 4                       2.288  33.0      1.0
# ..                        ...   ...      ...
# 763                     0.171  63.0      0.0
# 764                     0.340  27.0      0.0
# 765                     0.245  30.0      0.0
# 766                     0.349  47.0      1.0
# 767                     0.315  23.0      0.0
#
# [768 rows x 9 columns]

# %%
df7 = df2.dropna()
df7
# Out:
#      Pregnancies  Glucose  Blood Pressure  SkinThickness  Insulin   BMI  \
# 4            0.0      137            40.0             35      168  43.1
# 5            5.0      116            74.0              0        0  25.6
# 6            3.0       78            50.0             32       88  31.0
# 7           10.0      115             0.0              0        0  35.3
# 8            2.0      197            70.0             45      543  30.5
# ..           ...      ...             ...            ...      ...   ...
# 763         10.0      101            76.0             48      180  32.9
# 764          2.0      122            70.0             27        0  36.8
# 765          5.0      121            72.0             23      112  26.2
# 766          1.0      126            60.0              0        0  30.1
# 767          1.0       93            70.0             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 4                       2.288   33        1
# 5                       0.201   30        0
# 6                       0.248   26        1
# 7                       0.134   29        0
# 8                       0.158   53        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [764 rows x 9 columns]

# %%
df7 = df2.dropna(how = 'all')
df7
# Out:
#      Pregnancies  Glucose  Blood Pressure  SkinThickness  Insulin   BMI  \
# 0            NaN      148            72.0             35        0  33.6
# 1            1.0       85             NaN             29        0  26.6
# 2            8.0      183            64.0              0        0   NaN
# 3            1.0       89            66.0             23       94   NaN
# 4            0.0      137            40.0             35      168  43.1
# ..           ...      ...             ...            ...      ...   ...
# 763         10.0      101            76.0             48      180  32.9
# 764          2.0      122            70.0             27        0  36.8
# 765          5.0      121            72.0             23      112  26.2
# 766          1.0      126            60.0              0        0  30.1
# 767          1.0       93            70.0             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
df8 = df2.dropna(thresh = 9)
df8
# Out:
#      Pregnancies  Glucose  Blood Pressure  SkinThickness  Insulin   BMI  \
# 4            0.0      137            40.0             35      168  43.1
# 5            5.0      116            74.0              0        0  25.6
# 6            3.0       78            50.0             32       88  31.0
# 7           10.0      115             0.0              0        0  35.3
# 8            2.0      197            70.0             45      543  30.5
# ..           ...      ...             ...            ...      ...   ...
# 763         10.0      101            76.0             48      180  32.9
# 764          2.0      122            70.0             27        0  36.8
# 765          5.0      121            72.0             23      112  26.2
# 766          1.0      126            60.0              0        0  30.1
# 767          1.0       93            70.0             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 4                       2.288   33        1
# 5                       0.201   30        0
# 6                       0.248   26        1
# 7                       0.134   29        0
# 8                       0.158   53        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [764 rows x 9 columns]

# %% [markdown]
# ### Correlation

# %%
df2.head()
# Out:
#    Pregnancies  Glucose  Blood Pressure  SkinThickness  Insulin   BMI  \
# 0          NaN      148            72.0             35        0  33.6
# 1          1.0       85             NaN             29        0  26.6
# 2          8.0      183            64.0              0        0   NaN
# 3          1.0       89            66.0             23       94   NaN
# 4          0.0      137            40.0             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df2.corr()
# Out:
#                           Pregnancies   Glucose  Blood Pressure  \
# Pregnancies                  1.000000  0.128846        0.141088
# Glucose                      0.128846  1.000000        0.152482
# Blood Pressure               0.141088  0.152482        1.000000
# SkinThickness               -0.082495  0.057328        0.207523
# Insulin                     -0.072999  0.331357        0.088818
# BMI                          0.018795  0.224135        0.281555
# DiabetesPedigreeFunction    -0.033927  0.137337        0.041193
# Age                          0.544018  0.263514        0.239498
# Outcome                      0.221087  0.466581        0.064939
#
#                           SkinThickness   Insulin       BMI  \
# Pregnancies                   -0.082495 -0.072999  0.018795
# Glucose                        0.057328  0.331357  0.224135
# Blood Pressure                 0.207523  0.088818  0.281555
# SkinThickness                  1.000000  0.436783  0.391622
# Insulin                        0.436783  1.000000  0.197193
# BMI                            0.391622  0.197193  1.000000
# DiabetesPedigreeFunction       0.183928  0.185071  0.141168
# Age                           -0.113970 -0.042163  0.035476
# Outcome                        0.074752  0.130548  0.294930
#
#                           DiabetesPedigreeFunction       Age   Outcome
# Pregnancies                              -0.033927  0.544018  0.221087
# Glucose                                   0.137337  0.263514  0.466581
# Blood Pressure                            0.041193  0.239498  0.064939
# SkinThickness                             0.183928 -0.113970  0.074752
# Insulin                                   0.185071 -0.042163  0.130548
# BMI                                       0.141168  0.035476  0.294930
# DiabetesPedigreeFunction                  1.000000  0.033561  0.173844
# Age                                       0.033561  1.000000  0.238356
# Outcome                                   0.173844  0.238356  1.000000

# %%
df2[['Pregnancies', 'BMI', 'Age']].corr()
# Out:
#              Pregnancies       BMI       Age
# Pregnancies     1.000000  0.018795  0.544018
# BMI             0.018795  1.000000  0.035476
# Age             0.544018  0.035476  1.000000

# %% [markdown]
# ### Loc and iloc
#
# loc - location
#
# iloc - integer location

# %%
df2.iloc[:,:]
# Out:
#      Pregnancies  Glucose  Blood Pressure  SkinThickness  Insulin   BMI  \
# 0            NaN      148            72.0             35        0  33.6
# 1            1.0       85             NaN             29        0  26.6
# 2            8.0      183            64.0              0        0   NaN
# 3            1.0       89            66.0             23       94   NaN
# 4            0.0      137            40.0             35      168  43.1
# ..           ...      ...             ...            ...      ...   ...
# 763         10.0      101            76.0             48      180  32.9
# 764          2.0      122            70.0             27        0  36.8
# 765          5.0      121            72.0             23      112  26.2
# 766          1.0      126            60.0              0        0  30.1
# 767          1.0       93            70.0             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
df2.iloc[:,3]
# Out:
# 0      35
# 1      29
# 2       0
# 3      23
# 4      35
#        ..
# 763    48
# 764    27
# 765    23
# 766     0
# 767    31
# Name: SkinThickness, Length: 768, dtype: int64

# %%
df2.iloc[:,6]
# Out:
# 0      0.627
# 1      0.351
# 2      0.672
# 3      0.167
# 4      2.288
#        ...
# 763    0.171
# 764    0.340
# 765    0.245
# 766    0.349
# 767    0.315
# Name: DiabetesPedigreeFunction, Length: 768, dtype: float64

# %%
df2.iloc[:,[7,4,5]]
# Out:
#      Age  Insulin   BMI
# 0     50        0  33.6
# 1     31        0  26.6
# 2     32        0   NaN
# 3     21       94   NaN
# 4     33      168  43.1
# ..   ...      ...   ...
# 763   63      180  32.9
# 764   27        0  36.8
# 765   30      112  26.2
# 766   47        0  30.1
# 767   23        0  30.4
#
# [768 rows x 3 columns]

# %%
df2.iloc[11:34,[7,4,5]]
# Out:
#     Age  Insulin   BMI
# 11   34        0  38.0
# 12   57        0  27.1
# 13   59      846  30.1
# 14   51      175  25.8
# 15   32        0  30.0
# 16   31      230  45.8
# 17   31        0  29.6
# 18   33       83  43.3
# 19   32       96  34.6
# 20   27      235  39.3
# 21   50        0  35.4
# 22   41        0  39.8
# 23   29        0  29.0
# 24   51      146  36.6
# 25   41      115  31.1
# 26   43        0  39.4
# 27   22      140  23.2
# 28   57      110  22.2
# 29   38        0  34.1
# 30   60        0  36.0
# 31   28      245  31.6
# 32   22       54  24.8
# 33   28        0  19.9

# %%
df2.iloc[:,]
# Out:
#      Pregnancies  Glucose  Blood Pressure  SkinThickness  Insulin   BMI  \
# 0            NaN      148            72.0             35        0  33.6
# 1            1.0       85             NaN             29        0  26.6
# 2            8.0      183            64.0              0        0   NaN
# 3            1.0       89            66.0             23       94   NaN
# 4            0.0      137            40.0             35      168  43.1
# ..           ...      ...             ...            ...      ...   ...
# 763         10.0      101            76.0             48      180  32.9
# 764          2.0      122            70.0             27        0  36.8
# 765          5.0      121            72.0             23      112  26.2
# 766          1.0      126            60.0              0        0  30.1
# 767          1.0       93            70.0             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
loc_df = df2.loc[:, ['Outcome', 'Blood Pressure', 'BMI']]

# %%
loc_df
# Out:
#      Outcome  Blood Pressure   BMI
# 0          1            72.0  33.6
# 1          0             NaN  26.6
# 2          1            64.0   NaN
# 3          0            66.0   NaN
# 4          1            40.0  43.1
# ..       ...             ...   ...
# 763        0            76.0  32.9
# 764        0            70.0  36.8
# 765        0            72.0  26.2
# 766        1            60.0  30.1
# 767        0            70.0  30.4
#
# [768 rows x 3 columns]

# %%
df2.loc[[6,11,2], ['Outcome', 'Blood Pressure', 'BMI']]
# Out:
#     Outcome  Blood Pressure   BMI
# 6         1            50.0  31.0
# 11        1            74.0  38.0
# 2         1            64.0   NaN

# %%
df2.iloc[[6,11,2],:]
# Out:
#     Pregnancies  Glucose  Blood Pressure  SkinThickness  Insulin   BMI  \
# 6           3.0       78            50.0             32       88  31.0
# 11         10.0      168            74.0              0        0  38.0
# 2           8.0      183            64.0              0        0   NaN
#
#     DiabetesPedigreeFunction  Age  Outcome
# 6                      0.248   26        1
# 11                     0.537   34        1
# 2                      0.672   32        1

# %%
df2.loc[[6,11,2],:]
# Out:
#     Pregnancies  Glucose  Blood Pressure  SkinThickness  Insulin   BMI  \
# 6           3.0       78            50.0             32       88  31.0
# 11         10.0      168            74.0              0        0  38.0
# 2           8.0      183            64.0              0        0   NaN
#
#     DiabetesPedigreeFunction  Age  Outcome
# 6                      0.248   26        1
# 11                     0.537   34        1
# 2                      0.672   32        1

# %%
df2.iloc[[6,11,2],2:7]
# Out:
#     Blood Pressure  SkinThickness  Insulin   BMI  DiabetesPedigreeFunction
# 6             50.0             32       88  31.0                     0.248
# 11            74.0              0        0  38.0                     0.537
# 2             64.0              0        0   NaN                     0.672

# %%
df2.loc[[6,11,2],'Blood Pressure':'Age']
# Out:
#     Blood Pressure  SkinThickness  Insulin   BMI  DiabetesPedigreeFunction  \
# 6             50.0             32       88  31.0                     0.248
# 11            74.0              0        0  38.0                     0.537
# 2             64.0              0        0   NaN                     0.672
#
#     Age
# 6    26
# 11   34
# 2    32

# %%
df2.head()
# Out:
#    Pregnancies  Glucose  Blood Pressure  SkinThickness  Insulin   BMI  \
# 0          NaN      148            72.0             35        0  33.6
# 1          1.0       85             NaN             29        0  26.6
# 2          8.0      183            64.0              0        0   NaN
# 3          1.0       89            66.0             23       94   NaN
# 4          0.0      137            40.0             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df2.sort_values(by = 'Age')
# Out:
#      Pregnancies  Glucose  Blood Pressure  SkinThickness  Insulin   BMI  \
# 255          1.0      113            64.0             35        0  33.6
# 60           2.0       84             0.0              0        0   0.0
# 102          0.0      125            96.0              0        0  22.5
# 182          1.0        0            74.0             20       23  27.7
# 623          0.0       94            70.0             27      115  43.5
# ..           ...      ...             ...            ...      ...   ...
# 123          5.0      132            80.0              0        0  26.8
# 684          5.0      136            82.0              0        0   0.0
# 666          4.0      145            82.0             18        0  32.5
# 453          2.0      119             0.0              0        0  19.6
# 459          9.0      134            74.0             33       60  25.9
#
#      DiabetesPedigreeFunction  Age  Outcome
# 255                     0.543   21        1
# 60                      0.304   21        0
# 102                     0.262   21        0
# 182                     0.299   21        0
# 623                     0.347   21        0
# ..                        ...  ...      ...
# 123                     0.186   69        0
# 684                     0.640   69        0
# 666                     0.235   70        1
# 453                     0.832   72        0
# 459                     0.460   81        0
#
# [768 rows x 9 columns]

# %%
df2.sort_values(by = 'Age', ascending=False)
# Out:
#      Pregnancies  Glucose  Blood Pressure  SkinThickness  Insulin   BMI  \
# 459          9.0      134            74.0             33       60  25.9
# 453          2.0      119             0.0              0        0  19.6
# 666          4.0      145            82.0             18        0  32.5
# 123          5.0      132            80.0              0        0  26.8
# 684          5.0      136            82.0              0        0   0.0
# ..           ...      ...             ...            ...      ...   ...
# 240          1.0       91            64.0             24        0  29.2
# 136          0.0      100            70.0             26       50  30.8
# 382          1.0      109            60.0              8      182  25.4
# 392          1.0      131            64.0             14      415  23.7
# 271          2.0      108            62.0             32       56  25.2
#
#      DiabetesPedigreeFunction  Age  Outcome
# 459                     0.460   81        0
# 453                     0.832   72        0
# 666                     0.235   70        1
# 123                     0.186   69        0
# 684                     0.640   69        0
# ..                        ...  ...      ...
# 240                     0.192   21        0
# 136                     0.597   21        0
# 382                     0.947   21        0
# 392                     0.389   21        0
# 271                     0.128   21        0
#
# [768 rows x 9 columns]

# %%
df2.sort_values(by = ['Age', 'SkinThickness'], ascending=False)
# Out:
#      Pregnancies  Glucose  Blood Pressure  SkinThickness  Insulin   BMI  \
# 459          9.0      134            74.0             33       60  25.9
# 453          2.0      119             0.0              0        0  19.6
# 666          4.0      145            82.0             18        0  32.5
# 123          5.0      132            80.0              0        0  26.8
# 684          5.0      136            82.0              0        0   0.0
# ..           ...      ...             ...            ...      ...   ...
# 571          2.0      130            96.0              0        0  22.6
# 577          2.0      118            80.0              0        0  42.9
# 624          2.0      108            64.0              0        0  30.8
# 626          0.0      125            68.0              0        0  24.7
# 627          0.0      132            78.0              0        0  32.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 459                     0.460   81        0
# 453                     0.832   72        0
# 666                     0.235   70        1
# 123                     0.186   69        0
# 684                     0.640   69        0
# ..                        ...  ...      ...
# 571                     0.268   21        0
# 577                     0.693   21        1
# 624                     0.158   21        0
# 626                     0.206   21        0
# 627                     0.393   21        0
#
# [768 rows x 9 columns]

# %%
import seaborn as sns

# %%
sns.boxplot(x = 'BMI', data = df2)
# Out:
# <AxesSubplot:xlabel='BMI'>

# %%
sns.boxplot(x = 'Age', data = df2)
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
sns.distplot(df2['Insulin'])
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Insulin', ylabel='Density'>

# %%
sns.boxplot(x = 'Insulin', data = df2)
# Out:
# <AxesSubplot:xlabel='Insulin'>

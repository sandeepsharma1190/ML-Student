# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
way_1_import = pd.read_excel(r'C:\Users\LENOVO\Downloads\Datasets\sample_dates_data.xlsx')
way_1_import.head()
# Out:
#          date  age     sex     bmi  children smoker     region      charges
# 0  17/12/2022   19  female  27.900         0    yes  southwest  16884.92400
# 1  30/08/1990   18    male  33.770         1     no  southeast   1725.55230
# 2  28/06/1984   33    male  22.705         0     no  northwest  21984.47061
# 3  18/10/1984   28    male  33.000         3     no  southeast   4449.46200

# %%
from datetime import datetime
import calendar

# %%
way_1_import.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      4 non-null      object
#  1   age       4 non-null      int64
#  2   sex       4 non-null      object
#  3   bmi       4 non-null      float64
#  4   children  4 non-null      int64
#  5   smoker    4 non-null      object
#  6   region    4 non-null      object
#  7   charges   4 non-null      float64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 384.0+ bytes

# %%
df = way_1_import.copy()

# %%
df['date'] = pd.to_datetime(df['date'])
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_6196\3532345252.py:1: UserWarning: Parsing '17/12/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['date'] = pd.to_datetime(df['date'])
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_6196\3532345252.py:1: UserWarning: Parsing '30/08/1990' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['date'] = pd.to_datetime(df['date'])
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_6196\3532345252.py:1: UserWarning: Parsing '28/06/1984' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['date'] = pd.to_datetime(df['date'])
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_6196\3532345252.py:1: UserWarning: Parsing '18/10/1984' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['date'] = pd.to_datetime(df['date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      4 non-null      datetime64[ns]
#  1   age       4 non-null      int64
#  2   sex       4 non-null      object
#  3   bmi       4 non-null      float64
#  4   children  4 non-null      int64
#  5   smoker    4 non-null      object
#  6   region    4 non-null      object
#  7   charges   4 non-null      float64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(3)
# memory usage: 384.0+ bytes

# %%
df['month'] = df['date'].dt.month

# %%
df
# Out:
#         date  age     sex     bmi  children smoker     region      charges  \
# 0 2022-12-17   19  female  27.900         0    yes  southwest  16884.92400
# 1 1990-08-30   18    male  33.770         1     no  southeast   1725.55230
# 2 1984-06-28   33    male  22.705         0     no  northwest  21984.47061
# 3 1984-10-18   28    male  33.000         3     no  southeast   4449.46200
#
#    month
# 0     12
# 1      8
# 2      6
# 3     10

# %%
df['year'] = df['date'].dt.year

# %%
df['day'] = df['date'].dt.day

# %%
df
# Out:
#         date  age     sex     bmi  children smoker     region      charges  \
# 0 2022-12-17   19  female  27.900         0    yes  southwest  16884.92400
# 1 1990-08-30   18    male  33.770         1     no  southeast   1725.55230
# 2 1984-06-28   33    male  22.705         0     no  northwest  21984.47061
# 3 1984-10-18   28    male  33.000         3     no  southeast   4449.46200
#
#    month  year  day
# 0     12  2022   17
# 1      8  1990   30
# 2      6  1984   28
# 3     10  1984   18

# %%
df['month_name'] = df['month'].apply(lambda x:calendar.month_name[x])

# %%
df
# Out:
#         date  age     sex     bmi  children smoker     region      charges  \
# 0 2022-12-17   19  female  27.900         0    yes  southwest  16884.92400
# 1 1990-08-30   18    male  33.770         1     no  southeast   1725.55230
# 2 1984-06-28   33    male  22.705         0     no  northwest  21984.47061
# 3 1984-10-18   28    male  33.000         3     no  southeast   4449.46200
#
#    month  year  day month_name
# 0     12  2022   17   December
# 1      8  1990   30     August
# 2      6  1984   28       June
# 3     10  1984   18    October

# %%
file1 = pd.read_csv(r'C:\Users\LENOVO\Downloads\Datasets\insurance - Regression.csv')
file1.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# ### dummy variables

# %%
df = file1.copy()

# %%
data1 = pd.get_dummies(df, columns = ['sex', 'smoker', 'region'])
data1
# Out:
#       age     bmi  children      charges  sex_female  sex_male  smoker_no  \
# 0      19  27.900         0  16884.92400           1         0          0
# 1      18  33.770         1   1725.55230           0         1          1
# 2      28  33.000         3   4449.46200           0         1          1
# 3      33  22.705         0  21984.47061           0         1          1
# 4      32  28.880         0   3866.85520           0         1          1
# ...   ...     ...       ...          ...         ...       ...        ...
# 1333   50  30.970         3  10600.54830           0         1          1
# 1334   18  31.920         0   2205.98080           1         0          1
# 1335   18  36.850         0   1629.83350           1         0          1
# 1336   21  25.800         0   2007.94500           1         0          1
# 1337   61  29.070         0  29141.36030           1         0          0
#
#       smoker_yes  region_northeast  region_northwest  region_southeast  \
# ...

# %%
data2 = pd.get_dummies(df, columns = ['sex', 'smoker', 'region'], drop_first = True)
data2
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes  \
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
#       region_northwest  region_southeast  region_southwest
# 0                    0                 0                 1
# 1                    0                 1                 0
# ...

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# ### Grouping

# %%
grouping = df.groupby('region')

# %%
grouping

# %%
southwest = grouping.get_group('southwest')

# %%
southwest
# Out:
#       age     sex   bmi  children smoker     region      charges
# 0      19  female  27.9         0    yes  southwest  16884.92400
# 12     23    male  34.4         0     no  southwest   1826.84300
# 15     19    male  24.6         1     no  southwest   1837.23700
# 18     56    male  40.3         0     no  southwest  10602.38500
# 19     30    male  35.3         0    yes  southwest  36837.46700
# ...   ...     ...   ...       ...    ...        ...          ...
# 1316   19  female  20.6         0     no  southwest   1731.67700
# 1329   52    male  38.6         2     no  southwest  10325.20600
# 1331   23  female  33.4         0     no  southwest  10795.93733
# 1332   52  female  44.7         3     no  southwest  11411.68500
# 1336   21  female  25.8         0     no  southwest   2007.94500
#
# [325 rows x 7 columns]

# %%
for x, y in grouping:
    print (x)
    print(y)
# Out:
# northeast
#       age     sex     bmi  children smoker     region      charges
# 8      37    male  29.830         2     no  northeast   6406.41070
# 10     25    male  26.220         0     no  northeast   2721.32080
# 16     52  female  30.780         1     no  northeast  10797.33620
# 17     23    male  23.845         0     no  northeast   2395.17155
# 20     60  female  36.005         0     no  northeast  13228.84695
# ...   ...     ...     ...       ...    ...        ...          ...
# 1321   62    male  26.695         0    yes  northeast  28101.33305
# 1325   61    male  33.535         0     no  northeast  13143.33665
# 1326   42  female  32.870         0     no  northeast   7050.02130
# 1328   23  female  24.225         2     no  northeast  22395.74424
# 1334   18  female  31.920         0     no  northeast   2205.98080
#
# [324 rows x 7 columns]
# northwest
#       age     sex     bmi  children smoker     region      charges
# ...

# %%
for x, y in grouping:
    print (x, '\n', y)
# Out:
# northeast
#        age     sex     bmi  children smoker     region      charges
# 8      37    male  29.830         2     no  northeast   6406.41070
# 10     25    male  26.220         0     no  northeast   2721.32080
# 16     52  female  30.780         1     no  northeast  10797.33620
# 17     23    male  23.845         0     no  northeast   2395.17155
# 20     60  female  36.005         0     no  northeast  13228.84695
# ...   ...     ...     ...       ...    ...        ...          ...
# 1321   62    male  26.695         0    yes  northeast  28101.33305
# 1325   61    male  33.535         0     no  northeast  13143.33665
# 1326   42  female  32.870         0     no  northeast   7050.02130
# 1328   23  female  24.225         2     no  northeast  22395.74424
# 1334   18  female  31.920         0     no  northeast   2205.98080
#
# [324 rows x 7 columns]
# northwest
#        age     sex     bmi  children smoker     region      charges
# ...

# %%
sex_grouping = df.groupby('sex')

# %%
sex_grouping.get_group('male')
# Out:
#       age   sex     bmi  children smoker     region      charges
# 1      18  male  33.770         1     no  southeast   1725.55230
# 2      28  male  33.000         3     no  southeast   4449.46200
# 3      33  male  22.705         0     no  northwest  21984.47061
# 4      32  male  28.880         0     no  northwest   3866.85520
# 8      37  male  29.830         2     no  northeast   6406.41070
# ...   ...   ...     ...       ...    ...        ...          ...
# 1324   31  male  25.935         1     no  northwest   4239.89265
# 1325   61  male  33.535         0     no  northeast  13143.33665
# 1327   51  male  30.030         1     no  southeast   9377.90470
# 1329   52  male  38.600         2     no  southwest  10325.20600
# 1333   50  male  30.970         3     no  northwest  10600.54830
#
# [676 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot([1,2,3,6])

# %%
plt.plot([-1, -2, -3, -6], [6,7,8,9])

# %%
x = np.linspace(1,50,20)
x
# Out:
# array([ 1.        ,  3.57894737,  6.15789474,  8.73684211, 11.31578947,
#        13.89473684, 16.47368421, 19.05263158, 21.63157895, 24.21052632,
#        26.78947368, 29.36842105, 31.94736842, 34.52631579, 37.10526316,
#        39.68421053, 42.26315789, 44.84210526, 47.42105263, 50.        ])

# %%
plt.plot(x)

# %%
y = np.random.randint(1,50,20)
y
# Out:
# array([29,  5, 36, 43,  3, 41, 34, 26, 47,  9, 30,  5, 47, 16, 45,  7, 38,
#        25,  7, 38])

# %%
plt.plot(y)

# %%
plt.plot(x, y)

# %%
plt.plot(y, x, color = 'k')

# %%
plt.plot(y, x, color = 'k')

# %%
y = np.sort(y)
plt.plot(x, y)

# %%
plt.plot(x, y)
plt.show()

# %%
plt.plot(x, y)
plt.xlabel('X-axis')
plt.show()

# %%
plt.plot(x, y)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()

# %%
plt.plot(x, y, color = 'green')
plt.xlabel('X-axis')
plt.title('X vs Y')
plt.ylabel('Y-axis')
plt.show()

# %% [markdown]
# ## Subplot

# %%
plt.subplot(1,2,1)
# Out:
# <AxesSubplot:>

# %%
plt.subplot(2,2,2)
# Out:
# <AxesSubplot:>

# %%
plt.subplot(1,3,3)
# Out:
# <AxesSubplot:>

# %%
plt.subplot(1,3,1)
plt.subplot(1,3,2)
plt.subplot(1,3,3)
plt.tight_layout()

# %%
plt.subplot(2,2,1)
plt.subplot(2,2,2)
plt.subplot(2,2,3)
plt.subplot(2,2,4)

plt.tight_layout()

# %%
plt.subplot(2,2,1)
plt.subplot(2,2,2)
plt.subplot(2,2,3)
plt.subplot(2,2,4)
plt.tight_layout()

# %%
plt.subplot(2,2,1)
plt.plot(x,y,'red')

plt.subplot(2,2,2)
plt.plot(y,x,'green')

plt.subplot(2,2,3)
plt.plot(x,y,'black')

plt.subplot(2,2,4)
plt.plot(x,y,'cyan')

plt.tight_layout()

# %%
y
# Out:
# array([ 3,  5,  5,  7,  7,  9, 16, 25, 26, 29, 30, 34, 36, 38, 38, 41, 43,
#        45, 47, 47])

# %%
plt.plot(y)

# %%
plt.plot(y, marker = 'o', linestyle = '--')

# %%
plt.plot(y, marker = 'o', linestyle = ':')

# %%
plt.plot(y, marker = 'o', linestyle = ':', markersize = 10)

# %%
plt.plot(y, marker = 'o', linestyle = ':', markersize = 10, markerfacecolor = 'r')

# %%
plt.plot(y, marker = 'o', linestyle = ':', markersize = 10, markerfacecolor = 'r', markeredgecolor = 'black')

# %%
plt.plot(y, marker = 'o', linestyle = ':', markersize = 10, markerfacecolor = 'r', markeredgecolor = 'black', markeredgewidth = 2)
